# %% [raw]
# Data Visualization III
# • Use Iris dataset
# • Identify feature types
# • Plot: Histograms, Boxplots
# • Compare distributions and detect outliers

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print("Feature Types:\n")
print(df.dtypes)

# Numerical Features:
# sepal_length, sepal_width, petal_length, petal_width

# Categorical Feature:
# species
# Out:
# Feature Types:
#
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
print("Shape  : ",df.shape)
print("\nDimensions:  ",df.ndim)
print("\nSize:   ",df.size)
# Out:
# Shape  :  (150, 5)
#
# Dimensions:   2
#
# Size:    750

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Histograms (Feature Distribution)

df.hist(figsize=(10,8), edgecolor='black', bins=10)
plt.suptitle('Histograms of Iris Features')
plt.tight_layout()
plt.show()

# %% [raw]
# •	Sepal Length → values mostly between 5–6.5, slightly spread
# •	Sepal Width → near normal distribution, centered around ~3
# •	Petal Length → shows 2 clear groups (bimodal)
# •	Petal Width → also 2 clear groups (bimodal)
#
# Petal length and petal width show clearer separation between flower species -> classification
# Sepal features overlap more and are less useful for classification
# The dataset is mostly well distributed with only a few unusual values (possible outliers)

# %%
# Boxplots (Outlier Detection)
plt.figure(figsize=(12,8))

# Sepal Length
plt.subplot(2,2,1)
sns.boxplot(y=df['sepal_length'])
plt.title("Sepal Length")

# Sepal Width
plt.subplot(2,2,2)
sns.boxplot(y=df['sepal_width'])
plt.title("Sepal Width")

# Petal Length
plt.subplot(2,2,3)
sns.boxplot(y=df['petal_length'])
plt.title("Petal Length")

# Petal Width
plt.subplot(2,2,4)
sns.boxplot(y=df['petal_width'])
plt.title("Petal Width")

plt.tight_layout()
plt.show()

# %%
#  Compare distributions and identify outliers
print("\nDescriptive Statistics:")
print(df.describe())
# Out:
# Descriptive Statistics:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.843624     3.059732      3.748993     1.194631
# std        0.830851     0.436342      1.767791     0.762622
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.300000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Detect Outliers using IQR Method

print("\nOutliers:\n")

for col in df.columns[:-1]:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # Count outliers
    count = ((df[col] < lower) | (df[col] > upper)).sum()

    print(col, ":", count, "outliers")
# Out:
# Outliers:
#
# sepal_length : 0 outliers
# sepal_width : 4 outliers
# petal_length : 0 outliers
# petal_width : 0 outliers

# %% [raw]
# samples are in the Iris dataset?
# There are 150 samples.
#
# bin in histogram?
# A bin is an interval used to group data values.
#
# Histogram - shows frequency of numerical data distribution using bars
#
# identified from histogram?
# Distribution, spread, skewness, and patterns.
#
# Boxplot shows graphical summary of data using 5 numbers - min, Q1, median, Q3, max
#
# boxplots used?
# To detect outliers and compare distributions.
#
# quartile?
# Values dividing data into four equal parts.
#
# IQR is the difference between third quartile and first quartile.
#
# whiskers- lines showing spread of data excluding outliers
#
# outlier -  data that is far way from rest of data
#
# Lower Bound=Q1−1.5(IQR)
#
# Upper Bound=Q3+1.5(IQR)
#
# Why use 1.5 × IQR?
# It is a standard rule for detecting extreme values.
#
# subplot() do?
# Creates multiple plots in one figure.
#
# skewness measures assymetry of data distribution

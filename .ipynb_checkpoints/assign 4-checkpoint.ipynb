# %% [raw]
# Data Analytics I (Linear Regression)
# • Implement Linear Regression
# • Use Boston Housing Dataset
# • Predict house prices.
# • Evaluate model using appropriate metrics
# ----------------------------------------------------------------------------------------
# Boston Housing dataset is used for regression to predict house prices (MEDV) based on features like number of rooms, crime rate, pollution level, and income level of the area.
#
# Column	  Meaning
# CRIM	  Crime rate in the area
# ZN	      % of residential land for large houses
# INDUS	  Industrial area %
# CHAS	  Near river or not (1 = Yes, 0 = No)
# NOX	      Air pollution level
# RM	      Average number of rooms per house
# AGE	      % of old houses (built before 1940)
# DIS	      Distance to employment centers
# RAD	      Access to highways
# TAX	      Property tax rate
# PTRATIO	  Student-teacher ratio
# B	      Proportion of Black population (demographic feature)
# LSTAT	  % of lower income population
# MEDV	  Median house price (Target variable)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Boston_Housing.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB
# None

# %%
print(df.describe())
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
print("Shape  : ",df.shape)
print("\nDimensions:  ",df.ndim)
print("\nData type:\n",df.dtypes)
print("\nSize:   ",df.size)
# Out:
# Shape  :  (506, 14)
#
# Dimensions:   2
#
# Data type:
#  CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object
#
# Size:    7084

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
# handling missing values
df.fillna(df.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# define features and target
x=df.drop('MEDV',axis=1)
y=df['MEDV']

# %%
# split the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
# apply linear regression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Predict values
y_predict=model.predict(x_test)

# %%
#  Evaluation metrics
mae = mean_absolute_error(y_test, y_predict)
mse = mean_squared_error(y_test, y_predict)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_predict)

# %%
# Display results

# Lower MAE, MSE, RMSE indicate better model
# R² close to 1 means good performance


print("\nMAE:", round(mae, 2))
print("MSE:", round(mse, 2))
print("RMSE:", round(rmse, 2))
print("R2 Score:", round(r2, 2))
# Out:
# MAE: 3.26
# MSE: 21.24
# RMSE: 4.61
# R2 Score: 0.74

# %% [raw]
# MAE = 3.38
#     On average, the predicted price is wrong by 3.38
#     Small number means good prediction
#
# MSE = 20.91
#     This also measures error
#     Big mistakes are punished more
#
# RMSE = 4.57
#     Prediction is wrong by about 4.57 on average
#     (Like actual price difference)
#
# R² Score = 0.73
#     Model is 73% correct
#     Closer to 1 means better model

# %%
plt.figure(figsize=(5,5))

sns.scatterplot(x=y_test, y=y_predict)
# X-axis → actual prices (y_test)
# Y-axis → predicted prices (y_predict)

plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted House Prices")

# Draws a straight diagonal line
# This line represents perfect prediction (Actual = Predicted)
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--', linewidth=2)
plt.grid(True)
plt.show()

# %% [raw]
# The graph shows predicted vs actual prices;
# points closer to the diagonal line indicate better model accuracy in predicting the prices

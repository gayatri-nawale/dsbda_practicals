# %% [raw]
# Data Analytics III (Naïve Bayes)
# • Implement Naïve Bayes on Iris dataset
# • Compute Confusion Matrix
# • Calculate: Accuracy, Error Rate , Precision, Recall
# ----------------------------------------------------------------------------------------------------------------
#
# Dataset = Flower classification
#
# SepalLengthCm – length of sepal
# SepalWidthCm – width of sepal
# PetalLengthCm – length of petal
# PetalWidthCm – width of petal
# Species – target variable (Setosa, Versicolor, Virginica)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score,precision_score,confusion_matrix
from sklearn.naive_bayes import GaussianNB

# %%
df=pd.read_csv('Iris.csv')
print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# information
print("Shape:  ",df.shape)
print("\nDimensions:  ",df.ndim)
print("\nSize:  ",df.size)
print("\nData Type\n",df.dtypes)
print("\nColumns: \n",df.columns)
# Out:
# Shape:   (150, 5)
#
# Dimensions:   2
#
# Size:   750
#
# Data Type
#  SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object
#
# Columns:
#  Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
print(df.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# drop Id unnecary col
df.drop('Id',axis=1,inplace=True)

# %%
# define features and target
x=df.drop('Species',axis=1)
y=df['Species']

# %%
print(x)
print(y)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# ...

# %%
# split data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
# apply naive bayes
model=GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_predict=model.predict(x_test)

# %%
# confusion matrix
cm=confusion_matrix(y_test,y_predict)
print("Confusion Matrix : \n",cm)

# Class 1 → all 7 predicted correctly
# Class 2 → 10 correct, 1 wrong
# Class 3 → all 12 correct
# Out:
# Confusion Matrix :
#  [[ 7  0  0]
#  [ 0 10  1]
#  [ 0  0 12]]

# %%
# Evaluation Metrics
accuracy = accuracy_score(y_test, y_predict)
error_rate = 1 - accuracy
precision = precision_score(y_test, y_predict, average='macro')
recall = recall_score(y_test, y_predict, average='macro')

print("\nAccuracy:", round(accuracy, 2))
print("Error Rate:", round(error_rate, 2))
print("Precision:", round(precision, 2))
print("Recall:", round(recall, 2))
# Out:
# Accuracy: 0.97
# Error Rate: 0.03
# Precision: 0.97
# Recall: 0.97

# %% [raw]
# Accuracy: Model correctly predicts 97 out of 100 cases.
#
# Error Rate: Model makes mistakes in 3 out of 100 cases.
#
# Precision: When the model predicts a class, it is correct 97% of the time.
#
# Recall: The model correctly identifies 97% of all actual cases.

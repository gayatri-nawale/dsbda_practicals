# %%
import pandas as pd
import numpy as np

# %%
data={
    'Rollno':range(1,6),
    'oop':[34,33,np.nan,45,41],
    'wt':[np.nan,47,np.nan,31,39],
    'attendance':[80,68,77,78,85]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#    Rollno   oop    wt  attendance
# 0       1  34.0   NaN          80
# 1       2  33.0  47.0          68
# 2       3   NaN   NaN          77
# 3       4  45.0  31.0          78
# 4       5  41.0  39.0          85

# %%
df.to_csv('sample.csv',index=False)
